# %% [markdown]
# # Importing Libraries

# %%
# Importing Labraries 
import pandas as pd
import numpy as np
import os

# %%
df_ords = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\orders.csv', index_col =False)

# %%
df_prods = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\products.csv', index_col = False)

# %%
df_dep_t = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\departments.csv', index_col = False)

# %%
df_ords_prior = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\order_products__prior.csv', index_col =False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
path = r'C:\Users\alexg\InstacartBasketAnalysis'

# %%
df = pd.read_csv(os.path.join(path, '02Data','PreparedData', 'orders_products_combined.csv'), nrows=1000)

# %%
df
# Out:
#      Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2539329        1    prior             1          2
# 2             2   2539329        1    prior             1          2
# 3             3   2539329        1    prior             1          2
# 4             4   2539329        1    prior             1          2
# ..          ...       ...      ...      ...           ...        ...
# 995         995   1247527       12    prior             2          5
# 996         996   1247527       12    prior             2          5
# 997         997   1247527       12    prior             2          5
# 998         998   1247527       12    prior             2          5
# 999         999   1916106       12    prior             3          5
#
#      order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
df.to_csv(os.path.join(path, '02Data','PreparedData', 'orders_products_combined.csv'))

# %%
df.to_pickle(os.path.join(path, '02Data','PreparedData', 'orders_products_combined.pkl'))
