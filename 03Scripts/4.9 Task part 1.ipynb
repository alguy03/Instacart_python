# %%
# Importing Labraries 
import pandas as pd
import numpy as np
import os

# %%
df_customers = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\customers.csv', index_col = False)

# %%
df_customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
df_customers.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
df_customers.rename(columns = {'Surnam' : 'last_name'}, inplace = True)

# %%
df_customers.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
df_customers.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
df_customers.rename(columns = {'n_dependants' : 'dependants'}, inplace = True)

# %%
df_customers.rename(columns = {'fam_status' : 'marital_status'}, inplace = True)

# %%
df_customers.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
df_customers
# Out:
#         user_id first_name last_name  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
df_customers.describe()
# Out:
#              user_id            age     dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df_customers['user_id'] = df_customers['user_id'].astype('str')

# %%
df_customers.describe()
# Out:
#                  age     dependants         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %%
df_test = pd.DataFrame()

# %%
df_test['mix'] = ['a','b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
df_customers.isnull().sum()
# Out:
# user_id               0
# first_name        11259
# last_name             0
# gender                0
# state                 0
# age                   0
# date_joined           0
# dependants            0
# marital_status        0
# income                0
# dtype: int64

# %%
df_nan = df_customers[df_customers['first_name'].isnull() == True]

# %%
df_nan
# Out:
#        user_id first_name last_name  gender         state  age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependants marital_status  income
# ...

# %% [markdown]
#  The missing values here are first names, which are strings. String values can’t be imputed like numeric values. User_id is more import than first name. Plus locating the frist name of a customer should be a easy problem to fix. I will not make any changes to the missing data.

# %%
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, dependants, marital_status, income]
# Index: []

# %% [markdown]
# No duplicates

# %%
path = r'C:\Users\alexg\InstacartBasketAnalysis'

# %%
df_customers.to_csv(os.path.join(path, '02Data','PreparedData', 'customers_checked.csv'))

# %%
df_orders_checked = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\orders_checked.csv', index_col =False)

# %%
df_orders_checked
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                 0   2539329        1    prior             1          2
# 1                 1   2398795        1    prior             2          3
# 2                 2    473747        1    prior             3          3
# 3                 3   2254736        1    prior             4          4
# 4                 4    431534        1    prior             5          4
# ...             ...       ...      ...      ...           ...        ...
# 3421078     3421078   2266710   206209    prior            10          5
# 3421079     3421079   1854736   206209    prior            11          4
# 3421080     3421080    626363   206209    prior            12          1
# 3421081     3421081   2977660   206209    prior            13          1
# 3421082     3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
df_orders_checked.rename(columns = {'order_dow' : 'order_days_of_the_week'}, inplace = True)

# %%
df_orders_checked
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          order_days_of_the_week  order_hour_of_day  days_since_prior_order
# 0                             2                  8                     NaN
# ...

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_days_of_the_week', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_days_of_the_week',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df_customers_checked = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\customers_checked.csv', index_col =False)

# %%
df_orders_checked
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          order_days_of_the_week  order_hour_of_day  days_since_prior_order
# 0                             2                  8                     NaN
# ...

# %%
df_customers_checked
# Out:
#         Unnamed: 0  user_id first_name last_name  gender           state  age  \
# 0                0    26711    Deborah  Esquivel  Female        Missouri   48
# 1                1    33890   Patricia      Hart  Female      New Mexico   36
# 2                2    65803    Kenneth    Farley    Male           Idaho   35
# 3                3   125935   Michelle     Hicks  Female            Iowa   40
# 4                4   130797        Ann   Gilmore  Female        Maryland   26
# ...            ...      ...        ...       ...     ...             ...  ...
# 206204      206204   168073       Lisa      Case  Female  North Carolina   44
# 206205      206205    49635     Jeremy   Robbins    Male          Hawaii   62
# 206206      206206   135902      Doris  Richmond  Female        Missouri   66
# 206207      206207    81095       Rose   Rollins  Female      California   27
# 206208      206208    80148    Cynthia     Noble  Female        New York   55
#
# ...

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\ords_prods_merge.pkl')

# %%
ords_prods_merge
# Out:
#       Unnamed: 0  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              1           1  Chocolate Sandwich Cookies        61
# 2              2           1  Chocolate Sandwich Cookies        61
# 3              3           1  Chocolate Sandwich Cookies        61
# 4              4           1  Chocolate Sandwich Cookies        61
# ...          ...         ...                         ...       ...
# 9995        9995          28           Wheat Chex Cereal       121
# 9996        9996          28           Wheat Chex Cereal       121
# 9997        9997          28           Wheat Chex Cereal       121
# 9998        9998          28           Wheat Chex Cereal       121
# 9999        9999          28           Wheat Chex Cereal       121
#
#       department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0                19     5.8   3139998      138    prior            28  ...
# ...

# %%
df_customers_orders_merged = df_customers_checked.merge(df_orders_checked, on = 'user_id', indicator = True)

# %%
df_customers_orders_merged
# Out:
#          Unnamed: 0_x  user_id first_name last_name  gender     state  age  \
# 0                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 1                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 2                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 3                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 4                   0    26711    Deborah  Esquivel  Female  Missouri   48
# ...               ...      ...        ...       ...     ...       ...  ...
# 3421078        206208    80148    Cynthia     Noble  Female  New York   55
# 3421079        206208    80148    Cynthia     Noble  Female  New York   55
# 3421080        206208    80148    Cynthia     Noble  Female  New York   55
# 3421081        206208    80148    Cynthia     Noble  Female  New York   55
# 3421082        206208    80148    Cynthia     Noble  Female  New York   55
#
# ...

# %%
df_products_checked = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\products_checked.csv', index_col =False)

# %%
df_products_checked
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_customers_orders_merged.to_pickle(os.path.join(path, '02Data','PreparedData', 'df_customers_orders_merged.pkl'))

# %%
products = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\products.csv', index_col =False)

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
order_products__prior = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\order_products__prior.csv', index_col = False)

# %%
df_merged_large = df_ords.merge(order_products__prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
df_merged_large = df_merged_large.merge(products, on = 'product_id')

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
df_customers_orders_merged
# Out:
#          Unnamed: 0_x  user_id first_name last_name  gender     state  age  \
# 0                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 1                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 2                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 3                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 4                   0    26711    Deborah  Esquivel  Female  Missouri   48
# ...               ...      ...        ...       ...     ...       ...  ...
# 3421078        206208    80148    Cynthia     Noble  Female  New York   55
# 3421079        206208    80148    Cynthia     Noble  Female  New York   55
# 3421080        206208    80148    Cynthia     Noble  Female  New York   55
# 3421081        206208    80148    Cynthia     Noble  Female  New York   55
# 3421082        206208    80148    Cynthia     Noble  Female  New York   55
#
# ...

# %%
df_customers_orders_merged = df_customers_orders_merged.drop(columns = ['eval_set'])

# %%
df_customers_orders_merged
# Out:
#          Unnamed: 0_x  user_id first_name last_name  gender     state  age  \
# 0                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 1                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 2                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 3                   0    26711    Deborah  Esquivel  Female  Missouri   48
# 4                   0    26711    Deborah  Esquivel  Female  Missouri   48
# ...               ...      ...        ...       ...     ...       ...  ...
# 3421078        206208    80148    Cynthia     Noble  Female  New York   55
# 3421079        206208    80148    Cynthia     Noble  Female  New York   55
# 3421080        206208    80148    Cynthia     Noble  Female  New York   55
# 3421081        206208    80148    Cynthia     Noble  Female  New York   55
# 3421082        206208    80148    Cynthia     Noble  Female  New York   55
#
# ...

# %%
frames = [df_merged_large, df_customers]

# %%
df_merged_large = pd.concat(frames)

# %%
df_merged_large.to_csv(os.path.join(path, '02Data', 'PreparedData', 'orders_products_combined.csv'))

# %%
df_merged_large.to_pickle(os.path.join(path, '02Data', 'PreparedData', 'orders_products_combined.pkl'))
