# %%
# Importing Labraries 
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\ords_prods_merge.pkl')

# %%
df = ords_prods_merge[:100000]

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.head(10)
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
# 5           5           1  Chocolate Sandwich Cookies        61
# 6           6           1  Chocolate Sandwich Cookies        61
# 7           7           1  Chocolate Sandwich Cookies        61
# 8           8           1  Chocolate Sandwich Cookies        61
# 9           9           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  \
# 0             19     5.8   3139998      138    prior            28
# 1             19     5.8   1977647      138    prior            30
# ...

# %%
vars_list = ['product_id', 'product_name', 'aisle_id', 'department_id', 'prices', 'order_id', 'user_id', 'order_number', 'orders_day_of_ the_week', 'busiest_hours_of_the_day', 'days_since_prior_order', 'add_to _cart_order', 'recordered', '_merge', 'price_range', 'busiest_days']

# %%
vars_list
# Out:
# ['product_id',
#  'product_name',
#  'aisle_id',
#  'department_id',
#  'prices',
#  'order_id',
#  'user_id',
#  'order_number',
#  'orders_day_of_ the_week',
#  'busiest_hours_of_the_day',
#  'days_since_prior_order',
#  'add_to _cart_order',
#  'recordered',
#  '_merge',
#  'price_range',
#  'busiest_days']

# %%
path = r'C:\Users\alexg\InstacartBasketAnalysis'

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                13.271380
# 7                16.517564
# 8                18.200581
# 9                 7.750000
# 11               12.385214
# 12               15.462247
# 13               23.276190
# 14                9.701613
# 16                8.948718
# 17               10.764706
# 18               17.250000
# 19               18.728264

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     13.271380
# 7     16.517564
# 8     18.200581
# 9      7.750000
# 11    12.385214
# 12    15.462247
# 13    23.276190
# 14     9.701613
# 16     8.948718
# 17    10.764706
# 18    17.250000
# 19    18.728264
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                13.271380   1  88
# 7                16.517564   1  98
# 8                18.200581   1  95
# 9                 7.750000   1  15
# 11               12.385214   1  67
# 12               15.462247   1  95
# 13               23.276190   1  92
# 14                9.701613   1  49
# 16                8.948718   1  46
# 17               10.764706   1  34
# 18               17.250000   9  28
# 19               18.728264   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            1           1  Chocolate Sandwich Cookies        61
# 2            2           1  Chocolate Sandwich Cookies        61
# 3            3           1  Chocolate Sandwich Cookies        61
# 4            4           1  Chocolate Sandwich Cookies        61
# 5            5           1  Chocolate Sandwich Cookies        61
# 6            6           1  Chocolate Sandwich Cookies        61
# 7            7           1  Chocolate Sandwich Cookies        61
# 8            8           1  Chocolate Sandwich Cookies        61
# 9            9           1  Chocolate Sandwich Cookies        61
# 10          10           1  Chocolate Sandwich Cookies        61
# 11          11           1  Chocolate Sandwich Cookies        61
# 12          12           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            1           1  Chocolate Sandwich Cookies        61
# 2            2           1  Chocolate Sandwich Cookies        61
# 3            3           1  Chocolate Sandwich Cookies        61
# 4            4           1  Chocolate Sandwich Cookies        61
# ..         ...         ...                         ...       ...
# 95          95           1  Chocolate Sandwich Cookies        61
# 96          96           1  Chocolate Sandwich Cookies        61
# 97          97           1  Chocolate Sandwich Cookies        61
# 98          98           1  Chocolate Sandwich Cookies        61
# 99          99           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0              19     5.8   3139998      138    prior            28  ...
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            1           1  Chocolate Sandwich Cookies        61
# 2            2           1  Chocolate Sandwich Cookies        61
# 3            3           1  Chocolate Sandwich Cookies        61
# 4            4           1  Chocolate Sandwich Cookies        61
# 5            5           1  Chocolate Sandwich Cookies        61
# 6            6           1  Chocolate Sandwich Cookies        61
# 7            7           1  Chocolate Sandwich Cookies        61
# 8            8           1  Chocolate Sandwich Cookies        61
# 9            9           1  Chocolate Sandwich Cookies        61
# 10          10           1  Chocolate Sandwich Cookies        61
# 11          11           1  Chocolate Sandwich Cookies        61
# 12          12           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    4687
# New customer        3330
# Loyal customer      1983
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480  Regular customer            36
# 12     1480  Regular customer            38
# 13     1480  Regular customer            39
# 14     1494      New customer             6
# 15     1494      New customer             7
# 16     1494      New customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02Data','PreparedData', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.to_csv(os.path.join(path, '02Data','PreparedData', 'ords_prods_merge.csv'))
