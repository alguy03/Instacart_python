# %%
# Importing Labraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 01. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
df_orders_products_combined = pd.read_pickle(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\orders_products_combined.pkl')

# %%
df_products_wrangled = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\products_wrangled.csv', index_col = False)

# %%
df_prods = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\OriginalData\products.csv', index_col = False)

# %%
df_prods_checked = pd.read_csv(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\products_checked.csv', index_col = False)

# %% [markdown]
# 02. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
df_prods_checked.shape
# Out:
# (49693, 6)

# %%
df_prods_checked.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32640421, 23)

# %%
df_prods.describe
# Out:
# <bound method NDFrame.describe of        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# ...

# %%
df_products_wrangled.describe
# Out:
# <bound method NDFrame.describe of     Unnamed: 0       department
# 0            1           frozen
# 1            2            other
# 2            3           bakery
# 3            4          produce
# 4            5          alcohol
# 5            6    international
# 6            7        beverages
# 7            8             pets
# 8            9  dry goods pasta
# 9           10             bulk
# 10          11    personal care
# 11          12     meat seafood
# 12          13           pantry
# 13          14        breakfast
# 14          15     canned goods
# 15          16       dairy eggs
# 16          17        household
# 17          18           babies
# 18          19           snacks
# 19          20             deli
# 20          21          missing>

# %%
df_products_wrangled.shape
# Out:
# (21, 2)

# %%
df_orders_products_combined.describe
# Out:
# <bound method NDFrame.describe of          order_id user_id  order_number  orders_day_of_week  \
# 0       2539329.0       1           1.0                 2.0
# 1       2398795.0       1           2.0                 3.0
# 2        473747.0       1           3.0                 3.0
# 3       2254736.0       1           4.0                 4.0
# 4        431534.0       1           5.0                 4.0
# ...           ...     ...           ...                 ...
# 206204        NaN  168073           NaN                 NaN
# 206205        NaN   49635           NaN                 NaN
# 206206        NaN  135902           NaN                 NaN
# 206207        NaN   81095           NaN                 NaN
# 206208        NaN   80148           NaN                 NaN
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                     8.0                     NaN       196.0
# 1                     7.0                    15.0       196.0
# ...

# %%
df_merged_large_prods = df_prods.merge(df_orders_products_combined, on = ['product_id'], how = 'inner')

# %%
df_merged_large_prods
# Out:
#           product_id              product_name_x  aisle_id_x  department_id_x  \
# 0                  1  Chocolate Sandwich Cookies          61               19
# 1                  1  Chocolate Sandwich Cookies          61               19
# 2                  1  Chocolate Sandwich Cookies          61               19
# 3                  1  Chocolate Sandwich Cookies          61               19
# 4                  1  Chocolate Sandwich Cookies          61               19
# ...              ...                         ...         ...              ...
# 32437711       49688      Fresh Foaming Cleanser          73               11
# 32437712       49688      Fresh Foaming Cleanser          73               11
# 32437713       49688      Fresh Foaming Cleanser          73               11
# 32437714       49688      Fresh Foaming Cleanser          73               11
# 32437715       49688      Fresh Foaming Cleanser          73               11
#
# ...

# %%
df_merged_large_prods = df_merged_large_prods.drop(columns = ['eval_set'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df_merged_large_prods = df_merged_large_prods.drop(columns = ['eval_set'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
path = r'C:\Users\alexg\InstacartBasketAnalysis'

# %%
df_merged_large_prods.to_pickle(os.path.join(path, '02Data','PreparedData', 'orders_products_merged.pkl'))

# %%
df_merged_large_prods.to_csv(os.path.join(path, '02Data','PreparedData', 'orders_products_merged.csv'))
