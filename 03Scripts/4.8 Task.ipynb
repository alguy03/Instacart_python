# %% [markdown]
# #Importing Data

# %% [markdown]
# 01. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Importing Labraries 
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\alexg\InstacartBasketAnalysis\02Data\PreparedData\ords_prods_merge.pkl')

# %%
ords_prods_merge.shape
# Out:
# (10000, 22)

# %%
ords_prods_merge.head(10)
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
# 5           5           1  Chocolate Sandwich Cookies        61
# 6           6           1  Chocolate Sandwich Cookies        61
# 7           7           1  Chocolate Sandwich Cookies        61
# 8           8           1  Chocolate Sandwich Cookies        61
# 9           9           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     5.8   3139998      138    prior            28  ...
# 1             19     5.8   1977647      138    prior            30  ...
# ...

# %% [markdown]
# 02. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id').agg({'product_id': ['mean', 'min', 'max']})
# Out:
#               product_id
#                     mean min max
# department_id
# 1               9.183580   4  18
# 7               9.376046   3  20
# 8              25.854651  21  26
# 9              19.000000  19  19
# 11             24.867704   6  27
# 12             22.900552  17  23
# 13              2.428571   2   5
# 14             28.000000  28  28
# 16              9.000000   9   9
# 17             14.000000  14  14
# 18             15.000000  15  15
# 19             13.947486   1  25

# %%
ords_prods_merge.groupby('department_id').agg({'aisle_id': ['mean', 'min', 'max']})
# Out:
#                  aisle_id
#                      mean  min  max
# department_id
# 1               81.800456   38  119
# 7              109.926397   31  115
# 8               40.970930   40   41
# 9               63.000000   63   63
# 11              97.377432   11  127
# 12              48.767956   35   49
# 13              89.857143    5  104
# 14             121.000000  121  121
# 16             120.000000  120  120
# 17              74.000000   74   74
# 18              56.000000   56   56
# 19              30.078524    3  103

# %%
ords_prods_merge.groupby('department_id').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                   prices
#                     mean   min   max
# department_id
# 1               8.438540   1.1  10.6
# 7               7.798762   2.8   8.4
# 8              11.262209  10.0  11.3
# 9              12.000000  12.0  12.0
# 11              5.963813   1.1   9.5
# 12              8.347514   8.2  17.1
# 13              8.585714   4.3   9.3
# 14             10.100000  10.1  10.1
# 16              7.000000   7.0   7.0
# 17              6.500000   6.5   6.5
# 18             11.200000  11.2  11.2
# 19              3.704682   1.9   5.8

# %%
ords_prods_merge.groupby('department_id').agg({'order_id': ['mean', 'min', 'max']})
# Out:
#                    order_id
#                        mean    min      max
# department_id
# 1              1.703366e+06  11055  3407301
# 7              1.739175e+06   1532  3419167
# 8              1.712711e+06  10764  3413355
# 9              1.992872e+06  11272  3120778
# 11             1.721770e+06    829  3410356
# 12             1.686821e+06    791  3418830
# 13             1.723409e+06  12209  3365626
# 14             1.670960e+06    334  3399944
# 16             1.777873e+06  28662  3419470
# 17             1.630260e+06  23572  3160086
# 18             1.494195e+06  67199  2986875
# 19             1.729839e+06   1107  3419644

# %%
ords_prods_merge.groupby('department_id').agg({'user_id': ['mean', 'min', 'max']})
# Out:
#                      user_id
#                         mean    min     max
# department_id
# 1               97701.063854   1388  204904
# 7               99656.396788    115  206178
# 8              118177.436047   1534  198045
# 9              110387.500000  15310  167190
# 11              88830.319066    117  205344
# 12             105298.169429      2  205804
# 13              95991.809524   5652  203578
# 14              17851.322581    727   36936
# 16              90139.532051    225  203480
# 17             138235.117647  32429  203569
# 18             145165.000000  31159  202112
# 19             103364.280406    122  206027

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                13.271380   1  88
# 7                16.517564   1  98
# 8                18.200581   1  95
# 9                 7.750000   1  15
# 11               12.385214   1  67
# 12               15.462247   1  95
# 13               23.276190   1  92
# 14                9.701613   1  49
# 16                8.948718   1  46
# 17               10.764706   1  34
# 18               17.250000   9  28
# 19               18.728264   1  99

# %%
ords_prods_merge.groupby('department_id').agg({'days_since_prior_order': ['mean', 'min', 'max']})
# Out:
#               days_since_prior_order
#                                 mean  min   max
# department_id
# 1                          12.020126  0.0  30.0
# 7                          11.416637  0.0  30.0
# 8                          10.658462  0.0  30.0
# 9                          12.333333  6.0  24.0
# 11                         13.041322  0.0  30.0
# 12                         11.677259  0.0  30.0
# 13                         10.752475  0.0  30.0
# 14                         14.857143  1.0  30.0
# 16                         14.128571  0.0  30.0
# 17                         10.800000  3.0  30.0
# 18                          5.750000  2.0  14.0
# 19                         10.517287  0.0  30.0

# %%
ords_prods_merge.groupby('department_id').agg({'add_to_cart_order': ['mean', 'min', 'max']})
# Out:
#               add_to_cart_order
#                            mean min max
# department_id
# 1                      8.509692   1  42
# 7                      8.576112   1  66
# 8                      9.008721   1  51
# 9                     13.750000   1  25
# 11                     8.968872   1  42
# 12                    10.262431   1  48
# 13                     9.400000   1  45
# 14                     7.556452   1  49
# 16                     7.608974   1  48
# 17                     8.235294   1  19
# 18                     3.500000   1   6
# 19                     7.832549   1  74

# %%
ords_prods_merge.groupby('department_id').agg({'reordered': ['mean', 'min', 'max']})
# Out:
#               reordered
#                    mean min max
# department_id
# 1              0.499430   0   1
# 7              0.528270   0   1
# 8              0.723837   0   1
# 9              0.000000   0   0
# 11             0.420233   0   1
# 12             0.442910   0   1
# 13             0.200000   0   1
# 14             0.475806   0   1
# 16             0.525641   0   1
# 17             0.117647   0   1
# 18             0.250000   0   1
# 19             0.626455   0   1

# %%
ords_prods_merge.groupby('department_id').agg({'max_order': ['mean', 'min', 'max']})
# Out:
#                max_order
#                     mean min max
# department_id
# 1              20.037628   1  88
# 7              23.974573   1  98
# 8              30.630814   1  95
# 9               7.750000   1  15
# 11             17.610895   1  67
# 12             20.153775   1  95
# 13             26.333333   1  95
# 14             12.016129   1  49
# 16             12.506410   1  48
# 17             11.941176   1  34
# 18             20.000000   9  28
# 19             28.373297   1  99

# %% [markdown]
# 03. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# each column is broken down by mean, min, and max.

# %% [markdown]
# 04. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            1           1  Chocolate Sandwich Cookies        61
# 2            2           1  Chocolate Sandwich Cookies        61
# 3            3           1  Chocolate Sandwich Cookies        61
# 4            4           1  Chocolate Sandwich Cookies        61
# 5            5           1  Chocolate Sandwich Cookies        61
# 6            6           1  Chocolate Sandwich Cookies        61
# 7            7           1  Chocolate Sandwich Cookies        61
# 8            8           1  Chocolate Sandwich Cookies        61
# 9            9           1  Chocolate Sandwich Cookies        61
# 10          10           1  Chocolate Sandwich Cookies        61
# 11          11           1  Chocolate Sandwich Cookies        61
# 12          12           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %% [markdown]
# 05. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    4687
# New customer        3330
# Loyal customer      1983
# Name: loyalty_flag, dtype: int64

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'prices']].head(100)
# Out:
#     user_id      loyalty_flag  prices
# 0       138  Regular customer     5.8
# 1       138  Regular customer     5.8
# 2       709      New customer     5.8
# 3       764      New customer     5.8
# 4       764      New customer     5.8
# 5       777  Regular customer     5.8
# 6       825      New customer     5.8
# 7       910  Regular customer     5.8
# 8      1052  Regular customer     5.8
# 9      1052  Regular customer     5.8
# 10     1379      New customer     5.8
# 11     1480  Regular customer     5.8
# 12     1480  Regular customer     5.8
# 13     1480  Regular customer     5.8
# 14     1494      New customer     5.8
# 15     1494      New customer     5.8
# 16     1494      New customer     5.8
# 17     1540  Regular customer     5.8
# 18     1540  Regular customer     5.8
# 19     1540  Regular customer     5.8
# 20     1540  Regular customer     5.8
# 21     1540  Regular customer     5.8
# 22     1540  Regular customer     5.8
# 23     1540  Regular customer     5.8
# ...

# %% [markdown]
# 06. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge['prices'] = ords_prods_merge.groupby(['max_order'])['user_id'].transform(np.max)

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] >= 10) & (ords_prods_merge['prices'] > 10), 'big_spender_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 10, 'big_spender_flag'] = 'Low spender'

# %%
ords_prods_merge['big_spender_flag'].value_counts(dropna = False)
# Out:
# High spender    10000
# Name: big_spender_flag, dtype: int64

# %%
ords_prods_merge[['max_order', 'big_spender_flag', 'user_id']].head(10)
# Out:
#    max_order big_spender_flag  user_id
# 0     205273     High spender      138
# 1     205273     High spender      138
# 2     205273     High spender      709
# 3     205273     High spender      764
# 4     205273     High spender      764
# 5     205273     High spender      777
# 6     205273     High spender      825
# 7     205273     High spender      910
# 8     205273     High spender     1052
# 9     205273     High spender     1052

# %% [markdown]
# 07. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
ords_prods_merge['days_since_prior_order'] = ords_prods_merge.groupby(['max_order'])['user_id'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['days_since_prior_order'] <= 20) & (ords_prods_merge['days_since_prior_order'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['days_since_prior_order'] <= 10) & (ords_prods_merge['days_since_prior_order'] > 10), 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Non-frequent customer    10000
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'frequency_flag', 'max_order']].head(10)
# Out:
#    user_id         frequency_flag  max_order
# 0      138  Non-frequent customer     205273
# 1      138  Non-frequent customer     205273
# 2      709  Non-frequent customer     205273
# 3      764  Non-frequent customer     205273
# 4      764  Non-frequent customer     205273
# 5      777  Non-frequent customer     205273
# 6      825  Non-frequent customer     205273
# 7      910  Non-frequent customer     205273
# 8     1052  Non-frequent customer     205273
# 9     1052  Non-frequent customer     205273

# %%
path = r'C:\Users\alexg\InstacartBasketAnalysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02Data','PreparedData', 'ords_prods_merge_2.pkl'))

# %%
ords_prods_merge.to_csv(os.path.join(path, '02Data','PreparedData', 'ords_prods_merge_2.csv'))
